# %% [markdown]
# # Data exploration

# %%
import pandas as pd
import pandas.io.json as pd_json
import os
import numpy as np

pd.set_option('display.max_colwidth', -1) # display entire text

# %%
FILE_NAME = "asaltante"
OUTS_DIR = "out"
file_path = "{}/{}.json".format(OUTS_DIR, FILE_NAME)
abs_file_path = os.path.abspath(file_path)

# %%
df = pd.read_json(abs_file_path, lines=True)

# %%
df.count()
# Out:
# contributors                 0
# coordinates                  0
# created_at                   210
# entities                     210
# extended_entities            27
# favorite_count               210
# favorited                    210
# geo                          0
# id                           210
# id_str                       210
# in_reply_to_screen_name      36
# in_reply_to_status_id        30
# in_reply_to_status_id_str    30
# in_reply_to_user_id          36
# in_reply_to_user_id_str      36
# is_quote_status              210
# lang                         210
# metadata                     210
# place                        12
# possibly_sensitive           99
# quoted_status                3
# quoted_status_id             27
# quoted_status_id_str         27
# retweet_count                210
# retweeted                    210
# retweeted_status             114
# source                       210
# text                         210
# truncated                    210
# ...

# %%
df[df["place"].notnull()]
# Out:
#      contributors  coordinates          created_at  \
# 16  NaN           NaN          2019-06-24 18:22:21
# 28  NaN           NaN          2019-06-23 22:37:46
# 46  NaN           NaN          2019-06-21 15:52:34
# 47  NaN           NaN          2019-06-21 13:29:58
# 86  NaN           NaN          2019-06-24 18:22:21
# 98  NaN           NaN          2019-06-23 22:37:46
# 116 NaN           NaN          2019-06-21 15:52:34
# 117 NaN           NaN          2019-06-21 13:29:58
# 156 NaN           NaN          2019-06-24 18:22:21
# 168 NaN           NaN          2019-06-23 22:37:46
# 186 NaN           NaN          2019-06-21 15:52:34
# 187 NaN           NaN          2019-06-21 13:29:58
#
# ...

# %%
df[df["place"].notnull()]["place"]
# Out:
# 16     {u'name': u'Álvaro Obregón', u'url': u'https://api.twitter.com/1.1/geo/id/90a5d505052f7bae.json', u'country': u'Mexico', u'place_type': u'city', u'bounding_box': {u'type': u'Polygon', u'coordinates': [[[-99.324375, 19.232228], [-99.1716443, 19.232228], [-99.1716443, 19.403856], [-99.324375, 19.403856]]]}, u'contained_within': [], u'full_name': u'Álvaro Obregón, Distrito Federal', u'attributes': {}, u'country_code': u'MX', u'id': u'90a5d505052f7bae'}
# 28     {u'name': u'Cuauhtémoc', u'url': u'https://api.twitter.com/1.1/geo/id/bfc35dcc7e63252a.json', u'country': u'Mexico', u'place_type': u'city', u'bounding_box': {u'type': u'Polygon', u'coordinates': [[[-99.1843501, 19.3998346], [-99.122382, 19.3998346], [-99.122382, 19.4658366], [-99.1843501, 19.4658366]]]}, u'contained_within': [], u'full_name': u'Cuauhtémoc, Distrito Federal', u'attributes': {}, u'country_code': u'MX', u'id': u'bfc35dcc7e63252a'}
# ...

# %%
df.iloc[11]
# Out:
# contributors                 NaN
# coordinates                  NaN
# created_at                   2019-06-24 20:06:24
# entities                     {u'user_mentions': [{u'indices': [3, 14], u'id': 900122660537077762, u'id_str': u'900122660537077762', u'screen_name': u'telediario', u'name': u'Telediario Mx'}], u'symbols': [], u'hashtags': [{u'indices': [21, 30], u'text': u'Ecatepec'}], u'urls': []}
# extended_entities            NaN
# favorite_count               0
# favorited                    False
# geo                          NaN
# id                           1143249031197593601
# id_str                       1143249031197593600
# in_reply_to_screen_name      None
# in_reply_to_status_id        NaN
# in_reply_to_status_id_str    NaN
# in_reply_to_user_id          NaN
# in_reply_to_user_id_str      NaN
# ...
# source                       <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>
# ...

# %% [markdown]
# ## Remove duplicates

# %%
df_no_dup = df.drop_duplicates(subset="id", keep="first", inplace=False)
df_no_dup
# Out:
#     contributors  coordinates          created_at  \
# 0  NaN           NaN          2019-06-26 12:04:54
# 1  NaN           NaN          2019-06-26 05:08:53
# 2  NaN           NaN          2019-06-26 02:14:51
# 3  NaN           NaN          2019-06-25 23:11:21
# 4  NaN           NaN          2019-06-25 19:22:10
# 5  NaN           NaN          2019-06-25 16:44:56
# 6  NaN           NaN          2019-06-25 15:48:22
# 7  NaN           NaN          2019-06-25 15:24:27
# 8  NaN           NaN          2019-06-25 09:48:21
# 9  NaN           NaN          2019-06-25 04:09:51
# 10 NaN           NaN          2019-06-24 21:42:33
# 11 NaN           NaN          2019-06-24 20:06:24
# 12 NaN           NaN          2019-06-24 20:00:01
# 13 NaN           NaN          2019-06-24 19:39:21
# 14 NaN           NaN          2019-06-24 19:03:19
# 15 NaN           NaN          2019-06-24 18:23:03
# 16 NaN           NaN          2019-06-24 18:22:21
# 17 NaN           NaN          2019-06-24 15:41:32
# ...

# %%
df_no_dup.count()
# Out:
# contributors                 0
# coordinates                  0
# created_at                   70
# entities                     70
# extended_entities            9
# favorite_count               70
# favorited                    70
# geo                          0
# id                           70
# id_str                       70
# in_reply_to_screen_name      12
# in_reply_to_status_id        10
# in_reply_to_status_id_str    10
# in_reply_to_user_id          12
# in_reply_to_user_id_str      12
# is_quote_status              70
# lang                         70
# metadata                     70
# place                        4
# possibly_sensitive           33
# quoted_status                1
# quoted_status_id             9
# quoted_status_id_str         9
# retweet_count                70
# retweeted                    70
# retweeted_status             38
# source                       70
# text                         70
# truncated                    70
# ...

# %%
df_no_dup[df_no_dup["place"].notnull()]
# Out:
#     contributors  coordinates          created_at  \
# 16 NaN           NaN          2019-06-24 18:22:21
# 28 NaN           NaN          2019-06-23 22:37:46
# 46 NaN           NaN          2019-06-21 15:52:34
# 47 NaN           NaN          2019-06-21 13:29:58
#
# ...

# %%
df_no_dup.sort_values("favorite_count")["place"].head(15)
# Out:
# 0     None
# 33    None
# 68    None
# 36    None
# 37    None
# 38    None
# 39    None
# 40    None
# 41    None
# 42    None
# 43    None
# 46    {u'name': u'Álvaro Obregón', u'url': u'https://api.twitter.com/1.1/geo/id/90a5d505052f7bae.json', u'country': u'Mexico', u'place_type': u'city', u'bounding_box': {u'type': u'Polygon', u'coordinates': [[[-99.324375, 19.232228], [-99.1716443, 19.232228], [-99.1716443, 19.403856], [-99.324375, 19.403856]]]}, u'contained_within': [], u'full_name': u'Álvaro Obregón, Distrito Federal', u'attributes': {}, u'country_code': u'MX', u'id': u'90a5d505052f7bae'}
# ...

# %%
df_no_dup.iloc[46]["place"]
# Out:
# {u'attributes': {},
#  u'bounding_box': {u'coordinates': [[[-99.324375, 19.232228],
#     [-99.1716443, 19.232228],
#     [-99.1716443, 19.403856],
#     [-99.324375, 19.403856]]],
#   u'type': u'Polygon'},
#  u'contained_within': [],
#  u'country': u'Mexico',
#  u'country_code': u'MX',
#  u'full_name': u'\xc1lvaro Obreg\xf3n, Distrito Federal',
#  u'id': u'90a5d505052f7bae',
#  u'name': u'\xc1lvaro Obreg\xf3n',
#  u'place_type': u'city',
#  u'url': u'https://api.twitter.com/1.1/geo/id/90a5d505052f7bae.json'}

# %% [markdown]
# ## Remove unnecessary cols
